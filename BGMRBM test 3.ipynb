# %%
# TEST IF THE CHOICE OF FACE TO FIX WILL CHANGE THE RESULTING DISTRIBUTION

# %%
# %matplotlib inline

# %%
import datetime
dts = str(datetime.datetime.now())
date_time_str = dts[:10] + "-" + dts[11:13] + "-" + dts[14:16]
print date_time_str
# Out:
# 2015-01-26-19-14

# %%
import numpy as np

import matplotlib.pyplot as plt

import bga_4_0 as bga
import manifold_reflected_brownian_motion as mrbm

bga = reload(bga)
mrbm = reload(mrbm)

# %%
poly_name = 'octahedron'
int_num = 3

manifold_name = poly_name
manifold_kwargs_n = {'int_num': int_num, 'fixed_face': None}
manifold_kwargs_0 = {'int_num': int_num, 'fixed_face': 0}
manifold_kwargs_1 = {'int_num': int_num, 'fixed_face': 1}
manifold_kwargs_2 = {'int_num': int_num, 'fixed_face': 2}

boundary_name = poly_name
boundary_kwargs = {'int_num': int_num}

stat_name = 'test_2'
stat_kwargs = {}

# %%
err_tol = 10**-12
h = 0.025
N = 10**7
run_kwargs = {'N': N}

kwargs_n = {'stat_name': stat_name,
            'run_kwargs': run_kwargs, 
            'err_tol': err_tol,
            'manifold_kwargs': manifold_kwargs_n,
            'boundary_kwargs': {},
            'stat_kwargs': stat_kwargs}
kwargs_0 = {'stat_name': stat_name,
            'run_kwargs': run_kwargs, 
            'err_tol': err_tol,
            'manifold_kwargs': manifold_kwargs_0,
            'boundary_kwargs': {},
            'stat_kwargs': stat_kwargs}
kwargs_1 = {'stat_name': stat_name,
            'run_kwargs': run_kwargs, 
            'err_tol': err_tol,
            'manifold_kwargs': manifold_kwargs_1,
            'boundary_kwargs': {},
            'stat_kwargs': stat_kwargs}
kwargs_2 = {'stat_name': stat_name,
            'run_kwargs': run_kwargs, 
            'err_tol': err_tol,
            'manifold_kwargs': manifold_kwargs_2,
            'boundary_kwargs': {},
            'stat_kwargs': stat_kwargs}

# %%
x0, links, lengths, faces = bga.load_bg_int(poly_name, int_num)

# %%
z_n = mrbm.MRBM(manifold_name, 'none', x0, h, **kwargs_n)
z_0 = mrbm.MRBM(manifold_name, 'none', x0, h, **kwargs_0)
z_1 = mrbm.MRBM(manifold_name, 'none', x0, h, **kwargs_1)
z_2 = mrbm.MRBM(manifold_name, 'none', x0, h, **kwargs_2)

# %%
s_n = z_n.sample(N=N, record_trace=False, record_stats=True)
print 'done'
# Out:
# done

# %%
hist_n = plt.hist2d(z_n.stat_log[:,0], z_n.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_n'+date_time_str+'.png')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f62eb98abd8>

# %%
hist_n_0 = plt.hist(z_n.stat_log[:,0], bins=100, normed=True)
plt.savefig('test_3_n_x_'+date_time_str+'.png')

# %%
hist_n_1 = plt.hist(z_n.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_n_y_'+date_time_str+'.png')

# %%
s_0 = z_0.sample(N=N, record_trace=False, record_stats=True)
print 'done'
# Out:
# done

# %%
hist_0 = plt.hist2d(z_0.stat_log[:,0], z_0.stat_log[:,1], bins=100, normed=True)
plt.colorbar()
plt.savefig('test_3_0'+date_time_str+'.png')
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f62eb5d28c0>

# %%
hist_0_0 = plt.hist(z_0.stat_log[:,0], bins=100, normed=True)
plt.savefig('test_3_0_x_'+date_time_str+'.png')

# %%
hist_0_0 = plt.hist(z_0.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_0_y_'+date_time_str+'.png')

# %%
s_1 = z_1.sample(N=N, record_trace=False, record_stats=True)
print 'done'
# Out:
# done

# %%
hist_1 = plt.hist2d(z_1.stat_log[:,0], z_1.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_1'+date_time_str+'.png')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f62eb48d710>

# %%
hist_1_0 = plt.hist(z_1.stat_log[:,0], bins=100, normed=True)
plt.savefig('test_3_1_x_'+date_time_str+'.png')

# %%
hist_1_1 = plt.hist(z_1.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_1_y_'+date_time_str+'.png')

# %%
s_2 = z_2.sample(N=N, record_trace=False, record_stats=True)
print 'done'
# Out:
# done

# %%
hist_2 = plt.hist2d(z_2.stat_log[:,0], z_2.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_2'+date_time_str+'.png')
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f62eb351a70>

# %%
hist_2_0 = plt.hist(z_2.stat_log[:,0], bins=100, normed=True)
plt.savefig('test_3_2_x_'+date_time_str+'.png')

# %%
hist_2_1 = plt.hist(z_2.stat_log[:,1], bins=100, normed=True)
plt.savefig('test_3_2_y_'+date_time_str+'.png')
